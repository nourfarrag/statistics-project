# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import scipy as sc
import  statistics as st
import seaborn as sb

# %%
diabetes= pd.read_csv(r"C:/Users/DELL/OneDrive/Desktop/Diabetes Dataset.csv")
diabetes.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %% [markdown]
# # Correlation Matrix

# %%
diabetes.corr()
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.129459       0.141282      -0.081672
# Glucose                      0.129459  1.000000       0.152590       0.057328
# BloodPressure                0.141282  0.152590       1.000000       0.207371
# SkinThickness               -0.081672  0.057328       0.207371       1.000000
# Insulin                     -0.073535  0.331357       0.088933       0.436783
# BMI                          0.017683  0.221071       0.281805       0.392573
# DiabetesPedigreeFunction    -0.033523  0.137337       0.041265       0.183928
# Age                          0.544341  0.263514       0.239528      -0.113970
# Outcome                      0.221898  0.466581       0.065068       0.074752
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies              -0.073535  0.017683                 -0.033523
# ...

# %% [markdown]
# # Scattered plot

# %%
sb.scatterplot(x=diabetes['Glucose'], y=diabetes['Pregnancies'], color='blue')
plt.xlabel('Glucose')
plt.ylabel('Pregnancies')
plt.title('Glucose x Pregnancies')
# Out:
# Text(0.5, 1.0, 'Glucose x Pregnancies')

# %%
sb.scatterplot(x=diabetes['BMI'], y=diabetes['DiabetesPedigreeFunction'], color='orange')
plt.xlabel('BMI')
plt.ylabel('DiabetesPedigreeFunction')
plt.title('BMI x Diabetes Pedigree function')
# Out:
# Text(0.5, 1.0, 'BMI x Diabetes Pedigree function')

# %%
plt.scatter(x=diabetes['Glucose'], y=diabetes['Insulin'], color='green', label='Data Points')
plt.title('Glucose x Insulin')
# Out:
# Text(0.5, 1.0, 'Glucose x Insulin')

# %%
plt.scatter(x=diabetes['BloodPressure'], y=diabetes['Insulin'], color='red', label='Data Points')
plt.xlabel('Blood Pressure')
plt.ylabel('Insulin')
plt.title('Blood Pressure x Insulin')
# Out:
# Text(0.5, 1.0, 'Blood Pressure x Insulin')

# %%
plt.scatter(x=diabetes['SkinThickness'], y=diabetes['Outcome'], color='blue', label='Data Points')
plt.title('Skin thickness x Outcome')
# Out:
# Text(0.5, 1.0, 'Skin thickness x Outcome')

# %%
sb.pairplot(diabetes, kind='scatter')
# Out:
# C:\Users\DELL\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# # Line plots

# %%
plt.plot(diabetes['Age'] )
plt.plot(diabetes['Pregnancies'])
plt.title('pregnancies x  age')
plt.xlabel('Age')
plt.ylabel('pregnancies')
plt.show()

# %%
plt.plot(diabetes['Age'] )
plt.plot(diabetes['Insulin'])
plt.title('insulin x  age')
plt.xlabel('Age')
plt.ylabel('Insulin')
plt.show()

# %%
plt.plot(diabetes['SkinThickness'] )
plt.plot(diabetes['Age'])
plt.title('skin thickness x  age')
plt.xlabel('Age')
plt.ylabel('skin thickness')
plt.show()

# %%
plt.plot(diabetes['Age'] )
plt.plot(diabetes['DiabetesPedigreeFunction'])
plt.title('DiabetesPedigreeFunction x  age')
plt.xlabel('Age')
plt.ylabel('DiabetesPedigreeFunction')
plt.show()

# %%
plt.plot(diabetes['Age'] )
plt.plot(diabetes['Outcome'])
plt.title('outcome x  age')
plt.xlabel('Age')
plt.ylabel('outcome')
plt.show()

# %%
plt.plot(diabetes['Age'] )
plt.plot(diabetes['BMI'])
plt.title('BMI x  age')
plt.xlabel('Age')
plt.ylabel('BMI')
plt.show()

# %%
plt.plot(diabetes['Age'] )
plt.plot(diabetes['Glucose'])
plt.title('Glucose x  age')
plt.xlabel('Age')
plt.ylabel('Glucose')
plt.show()

# %%
plt.plot(diabetes['Age'] )
plt.plot(diabetes['BloodPressure'])
plt.title('BloodPressure x  age')
plt.xlabel('Age')
plt.ylabel('BloodPressure')
plt.show()

# %% [markdown]
# # Histograms

# %%
plt.hist(diabetes['Pregnancies'],color='skyblue',edgecolor='black')
plt.xlabel('Pregnancies')
plt.ylabel('Frequency')
plt.title('Histogram of Pregnancies in Diabetes')
# Out:
# Text(0.5, 1.0, 'Histogram of Pregnancies in Diabetes')

# %%
plt.hist(diabetes['BloodPressure'],color='violet',edgecolor='black')
plt.xlabel('Blood Pressure')
plt.ylabel('Frequency')
plt.title('Histogram of Blood Pressure in Diabetes ')
# Out:
# Text(0.5, 1.0, 'Histogram of Blood Pressure in Diabetes ')

# %%
plt.hist(diabetes['Glucose'],color='red',edgecolor='black')
plt.xlabel('Glucose')
plt.ylabel('Frequency')
plt.title('Histogram of Glucose in Diabetes')
# Out:
# Text(0.5, 1.0, 'Histogram of Glucose in Diabetes')

# %%
plt.hist(diabetes['SkinThickness'],color='blue',edgecolor='black')
plt.xlabel('Skin thickness')
plt.ylabel('Frequency')
plt.title('Histogram of Skin thickness in Diabetes')
# Out:
# Text(0.5, 1.0, 'Histogram of Skin thickness in Diabetes')

# %%
plt.hist(diabetes['Insulin'],color='green',edgecolor='black')
plt.xlabel('Insulin')
plt.ylabel('Frequency')
plt.title('Histogram of Insulin in Diabetes')
# Out:
# Text(0.5, 1.0, 'Histogram of Insulin in Diabetes')

# %%
plt.hist(diabetes['BMI'],color='orange',edgecolor='black')
plt.xlabel('BMI')
plt.ylabel('Frequency')
plt.title('Histogram of BMI in Diabetes')
# Out:
# Text(0.5, 1.0, 'Histogram of BMI in Diabetes')

# %%
plt.hist(diabetes['DiabetesPedigreeFunction'],color='Brown',edgecolor='black')
plt.xlabel('DiabetesPedigreeFunction')
plt.ylabel('Frequency')
plt.title('Histogram of DiabetesPedigreeFunction in Diabetes')
# Out:
# Text(0.5, 1.0, 'Histogram of DiabetesPedigreeFunction in Diabetes')

# %%
plt.hist(diabetes['Age'],color='yellow',edgecolor='black')
plt.xlabel('age')
plt.ylabel('Frequency')
plt.title('Histogram of Age in Diabetes')
# Out:
# Text(0.5, 1.0, 'Histogram of Age in Diabetes')

# %%
plt.hist(diabetes['Outcome'],color='grey',edgecolor='black')
plt.xlabel('Outcome')
plt.ylabel('Frequency')
plt.title('Histogram of Outcome in Diabetes')
# Out:
# Text(0.5, 1.0, 'Histogram of Outcome in Diabetes')

# %% [markdown]
# # Bar Plots

# %%
plt.bar(diabetes['Age'].unique(), diabetes['Age'].value_counts(), color='orange')
plt.xlabel('Age')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
plt.bar(diabetes['Pregnancies'].unique(), diabetes['Pregnancies'].value_counts(), color='skyblue')
plt.xlabel('Pregnancies')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
plt.bar(diabetes['Glucose'].unique(), diabetes['Glucose'].value_counts(), color='gold')
plt.xlabel('Glucose')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
plt.bar(diabetes['BloodPressure'].unique(), diabetes['BloodPressure'].value_counts(), color='red')
plt.xlabel('Blood pressure')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
plt.bar(diabetes['SkinThickness'].unique(), diabetes['SkinThickness'].value_counts(), color='black')
plt.xlabel('SkinThickness')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
plt.bar(diabetes['BMI'].unique(), diabetes['BMI'].value_counts(), color='GREEN')
plt.xlabel('BMI')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
plt.bar(diabetes['Outcome'].unique(), diabetes['Outcome'].value_counts(), color='violet')
plt.xlabel('outcome')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# # Pie Chart

# %%
frequency = diabetes['Pregnancies'].unique()
plt.pie([1] * len(frequency), labels=frequency, startangle=90, counterclock=False,autopct='%1.1f%%')
plt.title('Pie Chart of Pregnancies  ')
plt.show()

# %%
plt.title('Pie chart of Outcomes in Diabetes')
frequency = diabetes['Outcome'].value_counts()
plt.pie(frequency, labels=frequency.index, colors=['green', 'gold'],autopct='%1.1f%%')
plt.show()

# %%
cat_bins = [10,30, 50,70]
diabetes['Age'] = pd.cut(diabetes['Age'], bins=cat_bins)
frequency = diabetes['Age'].value_counts()
plt.pie(frequency, labels=frequency.index, startangle=90, counterclock=False, autopct='%1.1f%%')
plt.title('Pie Chart of Age ')
plt.show()

# %%
frequency = diabetes['Outcome'].value_counts()
plt.pie(frequency, labels=frequency.index, startangle=90, counterclock=False, autopct='%1.1f%%')
plt.title('Pie Chart of Outcome ')
plt.show()

# %%
cat_bins = [0, 60,90,120,150]
diabetes['Glucose'] = pd.cut(diabetes['Glucose'], bins=cat_bins)
frequency = diabetes['Glucose'].value_counts()
plt.pie(frequency, labels=frequency.index, startangle=90, counterclock=False, autopct='%1.1f%%')
plt.title('Pie Chart of Glucose ')
plt.show()

# %%
cat_bins = [0, 0.2,0.4,0.6,0.8,1]
diabetes['DiabetesPedigreeFunction'] = pd.cut(diabetes['DiabetesPedigreeFunction'], bins=cat_bins)
frequency = diabetes['DiabetesPedigreeFunction'].value_counts()
plt.pie(frequency, labels=frequency.index, startangle=90, counterclock=False, autopct='%1.1f%%')
plt.title('Pie Chart of DiabetesPedigreeFunction ')
plt.show()

# %%
cat_bins = [0, 10,20,30,40,50]
diabetes['SkinThickness'] = pd.cut(diabetes['SkinThickness'], bins=cat_bins)
frequency = diabetes['SkinThickness'].value_counts()
plt.pie(frequency, labels=frequency.index, startangle=90, counterclock=False, autopct='%1.1f%%')
plt.title('Pie Chart of SkinThickness ')
plt.show()

# %%
cat_bins = [10, 20,30,40,50]
diabetes['BMI'] = pd.cut(diabetes['BMI'], bins=cat_bins)
frequency = diabetes['BMI'].value_counts()
plt.pie(frequency, labels=frequency.index, startangle=90, counterclock=False, autopct='%1.1f%%')
plt.title('Pie Chart of BMI ')
plt.show()

# %%
cat_bins = [0, 200,400,600]
diabetes['Insulin'] = pd.cut(diabetes['Insulin'], bins=cat_bins)
frequency = diabetes['Insulin'].value_counts()
plt.pie(frequency, labels=frequency.index, startangle=90, counterclock=False, autopct='%1.1f%%')
plt.title('Pie Chart of Insulin ')
plt.show()

# %% [markdown]
# # Box plots

# %%
fig = plt.figure(figsize =(10, 7))
diabetes['Insulin'].plot(kind='box')
red_circle=dict(markerfacecolor='red', marker='o')
plt.boxplot(x=diabetes['Insulin'],flierprops=red_circle)
plt.xlabel('Insulin')
plt.ylabel('Values')
plt.title('Boxplot of Insulin ')
plt.show()

# %%
fig = plt.figure(figsize =(10, 7))
diabetes['Pregnancies'].plot(kind='box')
red_circle=dict(markerfacecolor='red', marker='o')
plt.boxplot(x=diabetes['Pregnancies'],flierprops=red_circle)
plt.xlabel('Pregnancies')
plt.ylabel('Values')
plt.title('Boxplot of Pregnancies in Diabetes Dataset')
plt.show()

# %%
fig = plt.figure(figsize =(10, 7))
diabetes['Glucose'].plot(kind='box')
red_circle=dict(markerfacecolor='red', marker='o')
plt.boxplot(x=diabetes['Glucose'],flierprops=red_circle)
plt.xlabel('Glucose')
plt.ylabel('Values')
plt.title('Boxplot of Glucose in Diabetes Dataset')
plt.show()

# %%
fig = plt.figure(figsize =(10, 7))
diabetes['BloodPressure'].plot(kind='box')
red_circle=dict(markerfacecolor='red', marker='o')
plt.boxplot(x=diabetes['BloodPressure'],flierprops=red_circle)
plt.xlabel('BloodPressure')
plt.ylabel('Values')
plt.title('Boxplot of BloodPressure in Diabetes Dataset')
plt.show()

# %%
fig = plt.figure(figsize =(10, 7))
diabetes['SkinThickness'].plot(kind='box')
red_circle=dict(markerfacecolor='red', marker='o')
plt.boxplot(x=diabetes['SkinThickness'],flierprops=red_circle)
plt.xlabel('SkinThickness')
plt.ylabel('Values')
plt.title('Boxplot of SkinThickness in Diabetes Dataset')
plt.show()

# %%
fig = plt.figure(figsize =(10, 7))
diabetes['BMI'].plot(kind='box')
red_circle=dict(markerfacecolor='red', marker='o')
plt.boxplot(x=diabetes['BMI'],flierprops=red_circle)
plt.xlabel('BMI')
plt.ylabel('Values')
plt.title('Boxplot of BMI in Diabetes Dataset')
plt.show()

# %%
fig = plt.figure(figsize =(10, 7))
diabetes['DiabetesPedigreeFunction'].plot(kind='box')
red_circle=dict(markerfacecolor='red', marker='o')
plt.boxplot(x=diabetes['DiabetesPedigreeFunction'],flierprops=red_circle)
plt.xlabel('Diabetes PedIGree function')
plt.ylabel('Values')
plt.title('Boxplot of DIabetes pedigree function in Diabetes Dataset')
plt.show()

# %%
fig = plt.figure(figsize =(10, 7))
diabetes['Age'].plot(kind='box')
red_circle=dict(markerfacecolor='red', marker='o')
plt.boxplot(x=diabetes['Age'],flierprops=red_circle)
plt.xlabel('Age')
plt.ylabel('Values')
plt.title('Boxplot of Age in Diabetes Dataset')
plt.show()

# %%
fig = plt.figure(figsize =(10, 7))
diabetes['Outcome'].plot(kind='box')
red_circle=dict(markerfacecolor='red', marker='o')
plt.boxplot(x=diabetes['Outcome'],flierprops=red_circle)
plt.xlabel('Outcome')
plt.ylabel('Values')
plt.title('Boxplot of Outcome in Diabetes Dataset')
plt.show()

# %%
diabetes=pd.DataFrame(np.random.rand(20,9),columns=['Pregnancies','Glucose','BloodPressure','Skin Thickness','Insulin','BMI','DiabetesPedigreeFunction','Age','Outcome'])
diabetes.plot.box(grid='True')
# Out:
# <Axes: >

# %% [markdown]
# # Probability Plots

# %%
probplot (diabetes['Pregnancies'],dist='norm',plot=plt)
plt.title('Pregnancies')
# Out:
# Text(0.5, 1.0, 'Pregnancies')

# %%
probplot (diabetes['Glucose'],dist='norm',plot=plt)
plt.title('Glucose')
# Out:
# Text(0.5, 1.0, 'Glucose')

# %%
probplot (diabetes['BloodPressure'],dist='norm',plot=plt)
plt.title('Blood Pressure')
# Out:
# Text(0.5, 1.0, 'Blood Pressure')

# %%
probplot (diabetes['SkinThickness'],dist='norm',plot=plt)
plt.title('Skin Thickness ')
# Out:
# Text(0.5, 1.0, 'Skin Thickness ')

# %%
probplot(diabetes['Insulin'],dist='norm',plot=plt)
plt.title(' Insulin')
# Out:
# Text(0.5, 1.0, ' Insulin')

# %%
probplot( diabetes['BMI'],dist='norm',plot=plt)
plt.title('BMI ')
# Out:
# Text(0.5, 1.0, 'BMI ')

# %%
probplot( diabetes['DiabetesPedigreeFunction'],dist='norm',plot=plt)
plt.title('DiabetesPedigreeFunction ')
# Out:
# Text(0.5, 1.0, 'DiabetesPedigreeFunction ')

# %%
probplot( diabetes['Age'],dist='norm',plot=plt)
plt.title('Age ')
# Out:
# Text(0.5, 1.0, 'Age ')

# %%
probplot( diabetes['Outcome'],dist='norm',plot=plt)
plt.title('Outcome')
# Out:
# Text(0.5, 1.0, 'Outcome')

# %%
from scipy.stats import probplot
plt.subplot(1,3,1)
probplot (diabetes['Pregnancies'],dist='norm',plot=plt)
plt.title('Pregnancies')
plt.subplot(1,3,2)
probplot (diabetes['Glucose'],dist='norm',plot=plt)
plt.title('Glucose')
plt.subplot(1,3,3)
probplot( diabetes['BMI'],dist='norm',plot=plt)
plt.title('BMI ')
# Out:
# Text(0.5, 1.0, 'BMI ')

# %%
plt.subplot(1,3,1)
probplot (diabetes['BloodPressure'],dist='norm',plot=plt)
plt.title('Blood Pressure')
plt.subplot(1,3,2)
probplot (diabetes['SkinThickness'],dist='norm',plot=plt)
plt.title('Skin Thickness ')
plt.subplot(1,3,3)
probplot(diabetes['Insulin'],dist='norm',plot=plt)
plt.title(' Insulin')
# Out:
# Text(0.5, 1.0, ' Insulin')

# %%
plt.subplot(1,3,1)
probplot( diabetes['DiabetesPedigreeFunction'],dist='norm',plot=plt)
plt.title('DiabetesPedigreeFunction ')
plt.subplot(1,3,2)

probplot( diabetes['Age'],dist='norm',plot=plt)
plt.title('Age ')
plt.subplot(1,3,3)
probplot( diabetes['Outcome'],dist='norm',plot=plt)
plt.title('Outcome')
# Out:
# Text(0.5, 1.0, 'Outcome')

# %% [markdown]
# # Heatmap

# %%
sns.heatmap(diabetes.corr(),cmap='coolwarm',annot=True)
# Out:
# <Axes: >

# %% [markdown]
# # Central Tendency

# %% [markdown]
# # MEAN

# %%
diabetes.mean()
# Out:
# Pregnancies                   3.845052
# Glucose                     120.894531
# BloodPressure                69.105469
# SkinThickness                20.536458
# Insulin                      79.799479
# BMI                          31.992578
# DiabetesPedigreeFunction      0.471876
# Age                          33.240885
# Outcome                       0.348958
# dtype: float64

# %% [markdown]
# # MEDIAN

# %%
diabetes.median()
# Out:
# Pregnancies                   3.0000
# Glucose                     117.0000
# BloodPressure                72.0000
# SkinThickness                23.0000
# Insulin                      30.5000
# BMI                          32.0000
# DiabetesPedigreeFunction      0.3725
# Age                          29.0000
# Outcome                       0.0000
# dtype: float64

# %% [markdown]
# # MODE

# %%
diabetes.mode()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0          1.0       99           70.0            0.0      0.0  32.0
# 1          NaN      100            NaN            NaN      NaN   NaN
#
#    DiabetesPedigreeFunction   Age  Outcome
# 0                     0.254  22.0      0.0
# 1                     0.258   NaN      NaN

# %% [markdown]
# # Dispersion

# %% [markdown]
# # STANDARD DEVIATION

# %%
diabetes.std()
# Out:
# Pregnancies                   3.369578
# Glucose                      31.972618
# BloodPressure                19.355807
# SkinThickness                15.952218
# Insulin                     115.244002
# BMI                           7.884160
# DiabetesPedigreeFunction      0.331329
# Age                          11.760232
# Outcome                       0.476951
# dtype: float64

# %% [markdown]
# # VARIANCE

# %%
diabetes.var()
# Out:
# Pregnancies                    11.354056
# Glucose                      1022.248314
# BloodPressure                 374.647271
# SkinThickness                 254.473245
# Insulin                     13281.180078
# BMI                            62.159984
# DiabetesPedigreeFunction        0.109779
# Age                           138.303046
# Outcome                         0.227483
# dtype: float64

# %% [markdown]
# # Quantiles

# %%
percentiles = [25, 50, 75]
quantiles = diabetes.quantile(q=[p/100 for p in percentiles])
print(quantiles)
# Out:
#       Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0.25          1.0    99.00           62.0            0.0     0.00  27.3
# 0.50          3.0   117.00           72.0           23.0    30.50  32.0
# 0.75          6.0   140.25           80.0           32.0   127.25  36.6
#
#       DiabetesPedigreeFunction   Age  Outcome
# 0.25                   0.24375  24.0      0.0
# 0.50                   0.37250  29.0      0.0
# 0.75                   0.62625  41.0      1.0

# %% [markdown]
# # Minimum values

# %%
 
    diabetes.min()
# Out:
# Pregnancies                  0.000
# Glucose                      0.000
# BloodPressure                0.000
# SkinThickness                0.000
# Insulin                      0.000
# BMI                          0.000
# DiabetesPedigreeFunction     0.078
# Age                         21.000
# Outcome                      0.000
# dtype: float64

# %% [markdown]
# # Maximum Values

# %%
diabetes.max()
# Out:
# Pregnancies                  17.00
# Glucose                     199.00
# BloodPressure               122.00
# SkinThickness                99.00
# Insulin                     846.00
# BMI                          67.10
# DiabetesPedigreeFunction      2.42
# Age                          81.00
# Outcome                       1.00
# dtype: float64
